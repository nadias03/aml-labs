# %%
# faq

# %%
# train test split
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.3,
    random_state=42
)

# %%
# accuracy
from sklearn.metrics import accuracy_score

acc = accuracy_score(y_test, y_pred)
print(acc)

# %%
# abalanced accuracy
from sklearn.metrics import balanced_accuracy_score

bal_acc = balanced_accuracy_score(y_test, y_pred)

# %%
# confusion matrix
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
print(cm)

#         Pred0 Pred1
# True0     TN    FP
# True1     FN    TP

# %%
# logistic regression
from sklearn.linear_model import LogisticRegression

clf = LogisticRegression()

clf.fit(X_train, y_train)

y_pred = clf.predict(X_test)

y_prob = clf.predict_proba(X_test)[:, 1]

# funkcja : p(x) = 1 / 1 + exp(-x)

# %%
# predict proba
probs = clf.predict_proba(X_test)

p_class0 = probs[:, 0]
p_class1 = probs[:, 1]

# %%
# roc curve
from sklearn.metrics import roc_curve

fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# FPR = FP/(FP+TN)

# TPR = TP/(TP+FN)

# %%
# roc auc
from sklearn.metrics import roc_auc_score

auc = roc_auc_score(y_test, y_prob)

# int
# 0.5 -> losowo
# 0.7-0.8 -> ok
# 0.8-0.9 -> dobrze
# >0.9 -> bardzo dobrze

# %%
# precision i recall
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score

precision = precision_score(y_test, y_pred)
recall = recall_score(y_test, y_pred)

# %%
# f1 score
from sklearn.metrics import f1_score

f1 = f1_score(y_test, y_pred)

# %%
# k-fold cv
from sklearn.model_selection import cross_val_score

scores = cross_val_score(
    clf,
    X,
    y,
    cv=10
)

print(scores.mean())

# %%
# decision tree
from sklearn.tree import DecisionTreeClassifier

tree = DecisionTreeClassifier(
    criterion="entropy",
    max_depth=5
)

tree.fit(X_train, y_train)

# most imp params
criterion="gini"
criterion="entropy"

max_depth=5

min_samples_split=5

min_samples_leaf=2

# %%
# cost complexity pruning
path = clf.cost_complexity_pruning_path(
    X_train,
    y_train
)

ccp_alphas = path.ccp_alphas

# potem: DecisionTreeClassifier(ccp_alpha=alpha)

# %%
# bagging
from sklearn.ensemble import BaggingClassifier

bag = BaggingClassifier(
    estimator=DecisionTreeClassifier(),
    n_estimators=100
)


# wiele bootstrapów
# +
# średnia / głosowanie
# =
# mniejsza wariancja

# %%
# random forest
from sklearn.ensemble import RandomForestClassifier

rf = RandomForestClassifier(
    n_estimators=100
)

# to vs bagging
# Bagging:
# losowanie obserwacji

# Random Forest:
# losowanie obserwacji
# +
# losowanie cech

# %%
# ada boost

from sklearn.ensemble import AdaBoostClassifier

ada = AdaBoostClassifier(
    n_estimators=100
)

# %%
# gradient boosting
from sklearn.ensemble import GradientBoostingClassifier

gb = GradientBoostingClassifier(
    n_estimators=100
)

# kolejne drzewa
# uczą się błędów
# poprzednich drzew

# %%
# xgb
from xgboost import XGBClassifier

xgb = XGBClassifier()

xgb.fit(X_train, y_train)

# %%
# feature importnace
importances = rf.feature_importances_

# posortowanie
idx = np.argsort(importances)[::-1]

# %%
# svm
from sklearn.svm import SVC

svm = SVC(
    kernel="linear"
)

# lub
svm = SVC(
    kernel="rbf"
)

# %%
# standaryzacja - wazna dls svm
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

# %%
# ndaraya-watson - najwazniejszy wzor z regresji
weights = kernel(x, X, h)

y_hat = np.sum(weights * y) / np.sum(weights)

# %%
# kernel gaussian
def gaussian_kernel(x, x_i, h):
    u = (x - x_i) / h

    return (
        1 / np.sqrt(2*np.pi)
    ) * np.exp(-0.5*u**2)

# %%
# kernel epanechnikov

def epanechnikov_kernel(x, x_i, h):
    u = (x - x_i) / h

    return np.where(
        np.abs(u) <= 1,
        0.75*(1-u**2),
        0
    )

# %%
# WYKRESY
# scatter
plt.scatter(X[:,0], X[:,1], c=y)

# histogram
plt.hist(x, bins=30)

# boxplot
plt.boxplot(results)

# line plot
plt.plot(x, y)

# %%
# bardziej
# scatter

# do: lda, qda, nb, lr, svm, drzewa

import matplotlib.pyplot as plt

plt.figure(figsize=(6,5))

plt.scatter(
    X[y==0, 0],
    X[y==0, 1],
    label="Class 0",
    marker="o"
)

plt.scatter(
    X[y==1, 0],
    X[y==1, 1],
    label="Class 1",
    marker="^"
)

plt.xlabel("X1")
plt.ylabel("X2")
plt.legend()
plt.show()

# %%
# boxplot wynikow modeli

# do: lda, qda, nb, realdatasets, porownywanie modeli

import pandas as pd
import matplotlib.pyplot as plt

df = pd.DataFrame({
    "LDA": lda_scores,
    "QDA": qda_scores,
    "NB": nb_scores
})

df.boxplot()

plt.ylabel("Accuracy")
plt.show()

# lub
plt.boxplot(
    [lda_scores, qda_scores, nb_scores],
    labels=["LDA", "QDA", "NB"]
)

plt.ylabel("Accuracy")
plt.show()

# %%
# box plot dla roznych parametrow
plt.figure(figsize=(10,5))

plt.boxplot(results)

plt.xticks(
    range(1, len(a_values)+1),
    a_values
)

plt.xlabel("a")
plt.ylabel("Accuracy")
plt.show()

# %%
# krzywa zaleznosci bledu od parametru

# do: kde, lr, feature selection, nw regression

plt.plot(x_values, mse_values)

plt.xlabel("n")
plt.ylabel("MSE")
plt.grid()
plt.show()

# %%
# wiele krzywych na jednym wykresie
plt.plot(n_values, mse1, label="Model 1")
plt.plot(n_values, mse2, label="Model 2")

plt.xlabel("n")
plt.ylabel("MSE")
plt.legend()
plt.grid()
plt.show()

# %%
# histogram + gestosc
plt.hist(
    X,
    bins=30,
    density=True,
    alpha=0.5
)

plt.plot(x_grid, true_density)

plt.show()

# %%
# prawdziwa gestosc vs kde
plt.plot(
    x_grid,
    true_density,
    label="True density"
)

plt.plot(
    x_grid,
    kde_density,
    label="KDE"
)

plt.legend()
plt.show()

# %%
# kilka bandwidthow na jednym wykresie
for h in [0.1, 0.5, 1]:
    plt.plot(
        x_grid,
        densities[h],
        label=f"h={h}"
    )

plt.legend()
plt.show()

# %%
# decision boundary

# do: lda, qda, logistic, svm

xx, yy = np.meshgrid(
    np.linspace(X[:,0].min()-1, X[:,0].max()+1, 200),
    np.linspace(X[:,1].min()-1, X[:,1].max()+1, 200)
)

grid = np.c_[xx.ravel(), yy.ravel()]

Z = model.predict(grid)
Z = Z.reshape(xx.shape)

plt.contourf(xx, yy, Z, alpha=0.3)

plt.scatter(X[:,0], X[:,1], c=y)

plt.show()

# %%
# decision boundary + countour (lepsza wersja)
proba = model.predict_proba(grid)[:,1]
proba = proba.reshape(xx.shape)

plt.contour(
    xx,
    yy,
    proba,
    levels=[0.5],
    colors="red"
)

plt.scatter(X[:,0], X[:,1], c=y)
plt.show()

# %%
# roc curve
from sklearn.metrics import roc_curve

fpr, tpr, _ = roc_curve(
    y_test,
    y_prob
)

plt.plot(fpr, tpr)

plt.plot(
    [0,1],
    [0,1],
    "--"
)

plt.xlabel("FPR")
plt.ylabel("TPR")
plt.show()

# %%
# precision recall curve
from sklearn.metrics import precision_recall_curve

precision, recall, _ = precision_recall_curve(
    y_test,
    y_prob
)

plt.plot(recall, precision)

plt.xlabel("Recall")
plt.ylabel("Precision")
plt.show()

# %%
# accuracy vs threshold
plt.plot(thresholds, acc_values)

plt.axvline(
    x=0.5,
    color="red",
    linestyle="--"
)

plt.xlabel("Threshold")
plt.ylabel("Accuracy")

plt.show()

# %%
# balanced accuracy vs threshold
plt.plot(thresholds, bal_acc_values)

plt.axvline(
    x=np.mean(y_train),
    color="red",
    linestyle="--"
)

plt.show()

# %%
# drzewo decyzyjne
from sklearn.tree import plot_tree

plt.figure(figsize=(20,10))

plot_tree(
    clf,
    filled=True
)

plt.show()

# %%
# cost complexity pruning
plt.plot(
    ccp_alphas,
    accuracies
)

plt.xlabel("ccp_alpha")
plt.ylabel("Accuracy")

plt.show()

# %%
# wspolczynniki lasso/ridge

for j in range(coefs.shape[1]):
    plt.plot(
        lambdas,
        coefs[:, j]
    )

plt.xscale("log")

plt.xlabel("lambda")
plt.ylabel("Coefficient")

plt.show()

# %%
# feature importance

idx = np.argsort(importances)

plt.barh(
    range(len(idx)),
    importances[idx]
)

plt.yticks(
    range(len(idx)),
    feature_names[idx]
)

plt.show()

# %%
# training error vs test error
plt.plot(
    n_trees,
    train_errors,
    label="Train"
)

plt.plot(
    n_trees,
    test_errors,
    label="Test"
)

plt.legend()
plt.show()

# %%
# nadaraya-watson - regresja
plt.scatter(
    X_train,
    y_train,
    alpha=0.5
)

plt.plot(
    x_grid,
    true_function,
    label="True"
)

plt.plot(
    x_grid,
    nw_estimate,
    label="NW"
)

plt.legend()
plt.show()

# %%
import numpy as np

class MyLogisticRegression:
    def __init__(self):
        self.beta0 = None      # intercept
        self.beta = None       # coefficients

    def fit(self, X, y):
        # tutaj zakładamy, że parametry już wyznaczyłaś
        pass

    def predict_proba(self, X):
        """
        Returns probabilities for classes 0 and 1.
        Shape: (n_samples, 2)
        """

        # linear part
        z = self.beta0 + X @ self.beta

        # sigmoid
        p1 = 1 / (1 + np.exp(-z))

        # probability of class 0
        p0 = 1 - p1

        return np.column_stack((p0, p1))

# %%
model = MyLogisticRegression()

model.beta0 = 0.5
model.beta = np.array([1.0, -0.5])

X = np.array([
    [2, 1],
    [0, 3],
    [1, 1]
])

print(model.predict_proba(X))
